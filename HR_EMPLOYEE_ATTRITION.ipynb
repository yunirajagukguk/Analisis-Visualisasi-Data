# %% [markdown]
# <a href="https://colab.research.google.com/github/yunirajagukguk/Analisis-Visualisasi-Data/blob/main/HR_EMPLOYEE_ATTRITION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Menampilkan Data

# %%
import pandas as pd

# Membaca data CSV
df = pd.read_csv('HR EMPLOYEE -ATTRITION.csv')

# Menampilkan 5 data pertama
(df.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
# Cek kolom, tipe, jumlah data
df.info()

# Cek statistik deskriptif
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#Cek Missing Value
print(df.isnull().sum())
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Distribusi Attrition

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x='Attrition', data=df)
plt.title('Distribusi Attrition')
plt.show()

# %% [markdown]
# Attrition Berdasarkan Gender

# %%
sns.countplot(x='Gender', hue='Attrition', data=df)
plt.title('Attrition Berdasarkan Gender')
plt.show()

# %% [markdown]
# Attrition Berdasarkan Job Role

# %%
plt.figure(figsize=(9,6))
sns.countplot(y='JobRole', hue='Attrition', data=df)
plt.title('Attrition Berdasarkan Job Role')
plt.show()

# %% [markdown]
# Distance From Home vs Attrition

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x='Attrition', y='DistanceFromHome', data=df)
plt.title('Distance From Home vs Attrition')
plt.show()

# %% [markdown]
# Pendapatan Perbulan vs Attrition

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x='Attrition', y='MonthlyIncome', data=df)
plt.title('Monthly Income vs Attrition')
plt.show()

# %% [markdown]
# Lembur vs Attrition

# %%
sns.countplot(x='OverTime', hue='Attrition', data=df)
plt.title('Overtime vs Attrition')
plt.show()

# %% [markdown]
# Rekayasa Fitur dan Pengkodean Kategorikal

# %% [markdown]
# Identifikasi Kolom Kategorikal

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %% [markdown]
# Target Pengkodean Label

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer

le = LabelEncoder()

kolom_kategori = [
  'Attrition',
  'BusinessTravel',
  'Department',
  'EducationField',
  'Gender',
  'JobRole',
  'MaritalStatus',
  'OverTime'
  ]

for col in kolom_kategori:
    df[col] = le.fit_transform(df[col])

# %% [markdown]
# Setelah Encoding

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# Feature Engineering

# %%
X = df.drop('Attrition', axis=1)

y = df['Attrition']

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Implementasikan Model yang Menyebabkan Karyawan Mengajukan Pengunduran Diri

# %% [markdown]
# Data Training & Testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# Model Machine Learning

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    class_weight='balanced'
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %% [markdown]
# Prediksi

# %%
prediksi = model.predict(X_test)

# %% [markdown]
# Evaluasi Model

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, prediksi))
print(classification_report(y_test, prediksi))
# Out:
# [[254   1]
#  [ 35   4]]
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93       255
#            1       0.80      0.10      0.18        39
#
#     accuracy                           0.88       294
#    macro avg       0.84      0.55      0.56       294
# weighted avg       0.87      0.88      0.83       294

# %% [markdown]
# Feature Importance

# %%
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': model.feature_importances_
}).sort_values(by='Importance', ascending=False)

print(importance.head(10))
# Out:
#               Feature  Importance
# 15      MonthlyIncome    0.079655
# 18           OverTime    0.074984
# 0                 Age    0.062163
# 2           DailyRate    0.049238
# 26     YearsAtCompany    0.048843
# 16        MonthlyRate    0.048594
# 23  TotalWorkingYears    0.045715
# 9          HourlyRate    0.045231
# 22   StockOptionLevel    0.044883
# 4    DistanceFromHome    0.039788
